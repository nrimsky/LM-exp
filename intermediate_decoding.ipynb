# %% [markdown]
# <a href="https://colab.research.google.com/github/nrimsky/LM-exp/blob/main/intermediate_decoding.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %%capture
# !pip install transformers

# %%
token = input("Enter your HF token: ")

# %%
import torch
from transformers import AutoTokenizer, AutoModelForCausalLM

class AttnWrapper(torch.nn.Module):
    def __init__(self, attn):
        super().__init__()
        self.attn = attn
        self.activations = None
        self.add_tensor = None

    def forward(self, *args, **kwargs):
        output = self.attn(*args, **kwargs)
        if self.add_tensor is not None:
            output = (output[0] + self.add_tensor,)+output[1:]
        self.activations = output[0]
        return output

    def reset(self):
        self.activations = None
        self.add_tensor = None

class BlockOutputWrapper(torch.nn.Module):
    def __init__(self, block, unembed_matrix, norm):
        super().__init__()
        self.block = block
        self.unembed_matrix = unembed_matrix
        self.norm = norm

        self.block.self_attn = AttnWrapper(self.block.self_attn)
        self.post_attention_layernorm = self.block.post_attention_layernorm

        self.attn_mech_output_unembedded = None
        self.intermediate_res_unembedded = None
        self.mlp_output_unembedded = None
        self.block_output_unembedded = None


    def forward(self, *args, **kwargs):
        output = self.block(*args, **kwargs)
        self.block_output_unembedded = self.unembed_matrix(self.norm(output[0]))
        attn_output = self.block.self_attn.activations
        self.attn_mech_output_unembedded = self.unembed_matrix(self.norm(attn_output))
        attn_output += args[0]
        self.intermediate_res_unembedded = self.unembed_matrix(self.norm(attn_output))
        mlp_output = self.block.mlp(self.post_attention_layernorm(attn_output))
        self.mlp_output_unembedded = self.unembed_matrix(self.norm(mlp_output))
        return output

    def attn_add_tensor(self, tensor):
        self.block.self_attn.add_tensor = tensor

    def reset(self):
        self.block.self_attn.reset()

    def get_attn_activations(self):
        return self.block.self_attn.activations

class Llama7BHelper:
    def __init__(self, token):
        self.device = "cuda" if torch.cuda.is_available() else "cpu"
        self.tokenizer = AutoTokenizer.from_pretrained("meta-llama/Llama-2-7b-hf", use_auth_token=token)
        self.model = AutoModelForCausalLM.from_pretrained("meta-llama/Llama-2-7b-hf", use_auth_token=token).to(self.device)
        for i, layer in enumerate(self.model.model.layers):
            self.model.model.layers[i] = BlockOutputWrapper(layer, self.model.lm_head, self.model.model.norm)

    def generate_text(self, prompt, max_length=100):
        inputs = self.tokenizer(prompt, return_tensors="pt")
        generate_ids = self.model.generate(inputs.input_ids.to(self.device), max_length=max_length)
        return self.tokenizer.batch_decode(generate_ids, skip_special_tokens=True, clean_up_tokenization_spaces=False)[0]

    def get_logits(self, prompt):
        inputs = self.tokenizer(prompt, return_tensors="pt")
        with torch.no_grad():
          logits = self.model(inputs.input_ids.to(self.device)).logits
          return logits

    def set_add_attn_output(self, layer, add_output):
        self.model.model.layers[layer].attn_add_tensor(add_output)

    def get_attn_activations(self, layer):
        return self.model.model.layers[layer].get_attn_activations()

    def reset_all(self):
        for layer in self.model.model.layers:
            layer.reset()

    def print_decoded_activations(self, decoded_activations, label):
        softmaxed = torch.nn.functional.softmax(decoded_activations[0][-1], dim=-1)
        values, indices = torch.topk(softmaxed, 10)
        probs_percent = [int(v * 100) for v in values.tolist()]
        tokens = self.tokenizer.batch_decode(indices.unsqueeze(-1))
        print(label, list(zip(tokens, probs_percent)))


    def decode_all_layers(self, text, topk=10, print_attn_mech=True, print_intermediate_res=True, print_mlp=True, print_block=True):
        self.get_logits(text)
        for i, layer in enumerate(self.model.model.layers):
            print(f'Layer {i}: Decoded intermediate outputs')
            if print_attn_mech:
                self.print_decoded_activations(layer.attn_mech_output_unembedded, 'Attention mechanism')
            if print_intermediate_res:
                self.print_decoded_activations(layer.intermediate_res_unembedded, 'Intermediate residual stream')
            if print_mlp:
                self.print_decoded_activations(layer.mlp_output_unembedded, 'MLP output')
            if print_block:
                self.print_decoded_activations(layer.block_output_unembedded, 'Block output')

# %%
model = Llama7BHelper(token)
# Out:
# Downloading (…)okenizer_config.json:   0%|          | 0.00/749 [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:1714: FutureWarning: The `use_auth_token` argument is deprecated and will be removed in v5 of Transformers.
#   warnings.warn(
# Downloading tokenizer.model:   0%|          | 0.00/500k [00:00<?, ?B/s]
# Downloading (…)/main/tokenizer.json:   0%|          | 0.00/1.84M [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/414 [00:00<?, ?B/s]
# Downloading (…)lve/main/config.json:   0%|          | 0.00/652 [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/transformers/modeling_utils.py:2193: FutureWarning: The `use_auth_token` argument is deprecated and will be removed in v5 of Transformers.
#   warnings.warn(
# Downloading (…)fetensors.index.json:   0%|          | 0.00/26.8k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/2 [00:00<?, ?it/s]
# Downloading (…)of-00002.safetensors:   0%|          | 0.00/9.98G [00:00<?, ?B/s]
# Downloading (…)of-00002.safetensors:   0%|          | 0.00/3.50G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# Downloading (…)neration_config.json:   0%|          | 0.00/175 [00:00<?, ?B/s]

# %%
model.decode_all_layers('The most important political question in the world is', print_intermediate_res=False, print_mlp=False,print_block=False)
# Out:
# Layer 0: Decoded intermediate outputs
# Attention mechanism [('пута', 8), ('totalité', 0), ('Архив', 0), ('瀬', 0), ('津', 0), ('cí', 0), ('férences', 0), ('Außer', 0), ('Ě', 0), ('telt', 0)]
# Layer 1: Decoded intermediate outputs
# Attention mechanism [('ˇ', 1), ('‖', 0), ('%%%%', 0), ('RewriteRule', 0), ('Ā', 0), ('�', 0), ('Fiche', 0), ('∣', 0), ('références', 0), ('irre', 0)]
# Layer 2: Decoded intermediate outputs
# Attention mechanism [('ever', 7), ('au', 0), ('erade', 0), ('orie', 0), ('�', 0), ('audi', 0), ('beg', 0), ('пан', 0), ('oteca', 0), ('zej', 0)]
# Layer 3: Decoded intermediate outputs
# Attention mechanism [('cowo', 2), ('ischof', 1), ('amar', 0), ('ง', 0), ('izont', 0), ('san', 0), ('rror', 0), ('keiten', 0), ('ellett', 0), ('webdriver', 0)]
# Layer 4: Decoded intermediate outputs
# Attention mechanism [('EXISTS', 5), ('antin', 1), ('BeanFactory', 1), ('données', 1), ('servlet', 0), ('\u200f', 0), ('LENG', 0), ('Kant', 0), ('ós', 0), ('database', 0)]
# Layer 5: Decoded intermediate outputs
# Attention mechanism [('Rep', 1), ('reputation', 0), ('gh', 0), ('RIG', 0), ('题', 0), ('Пра', 0), ('mel', 0), ('oid', 0), ('tap', 0), ('йт', 0)]
# Layer 6: Decoded intermediate outputs
# Attention mechanism [('ousel', 1), ('Duke', 0), ('duc', 0), ('urale', 0), ('vod', 0), ('widet', 0), ('ardin', 0), ('ifique', 0), ('sdl', 0), ('♠', 0)]
# Layer 7: Decoded intermediate outputs
# Attention mechanism [('questions', 5), ('question', 2), ('ksam', 1), ('questions', 1), ('rif', 1), ('enser', 1), ('tun', 0), ('igkeiten', 0), ('hos', 0), ('nitt', 0)]
# Layer 8: Decoded intermediate outputs
# Attention mechanism [('Bedeut', 2), ('nederbörd', 1), ('Mare', 1), ('nete', 1), ('öm', 0), ('Außer', 0), ('ћа', 0), ('ąd', 0), ('estaven', 0), ('Marsh', 0)]
# Layer 9: Decoded intermediate outputs
# Attention mechanism [('bru', 2), ('inek', 1), ('font', 0), ('zent', 0), ('igkeiten', 0), ('mit', 0), ('pty', 0), ('skap', 0), ('osed', 0), ('@@', 0)]
# Layer 10: Decoded intermediate outputs
# Attention mechanism [('widet', 13), ('elect', 0), ('ns', 0), ('Answer', 0), ('hd', 0), ('cel', 0), ('power', 0), ('reader', 0), ('ши', 0), ('are', 0)]
# Layer 11: Decoded intermediate outputs
# Attention mechanism [('iek', 1), ('capac', 1), ('rez', 1), ('ugel', 0), ('superfic', 0), ('Arnold', 0), ('ütt', 0), ('ění', 0), ('enschaft', 0), ('ountry', 0)]
# Layer 12: Decoded intermediate outputs
# Attention mechanism [('whether', 12), ('questions', 2), ('ois', 1), ('mas', 0), ('achi', 0), ('SEE', 0), ('Whether', 0), ('Trace', 0), ('iche', 0), ('rache', 0)]
# Layer 13: Decoded intermediate outputs
# Attention mechanism [('iddle', 2), ('ær', 1), ('widet', 1), ('cop', 1), ('clou', 0), ('chod', 0), ('nehmen', 0), ('состоя', 0), ('amos', 0), ('inflate', 0)]
# Layer 14: Decoded intermediate outputs
# Attention mechanism [('lau', 3), ('aml', 1), ('Nam', 0), ('ене', 0), ('ragen', 0), ('jus', 0), ('Wa', 0), ('Nur', 0), ('idi', 0), ('Wikimedia', 0)]
# Layer 15: Decoded intermediate outputs
# Attention mechanism [('igten', 9), ('än', 3), ('hören', 1), ('resolution', 0), ('ilib', 0), ('Ő', 0), ('trz', 0), ('kazy', 0), ('label', 0), ('stat', 0)]
# Layer 16: Decoded intermediate outputs
# Attention mechanism [('answered', 31), ('questions', 5), ('questions', 2), ('solved', 1), ('问', 1), ('answer', 1), ('oust', 1), ('answer', 1), ('answering', 1), ('estaven', 0)]
# Layer 17: Decoded intermediate outputs
# Attention mechanism [('för', 3), ('whether', 2), ('aws', 2), ('how', 2), ('contre', 1), ('ün', 1), ('ermeister', 1), ('jön', 1), ('quelle', 1), ('ittest', 1)]
# Layer 18: Decoded intermediate outputs
# Attention mechanism [('questions', 91), ('questions', 3), ('politics', 1), ('question', 0), ('political', 0), ('Question', 0), ('polit', 0), ('Polit', 0), ('政', 0), ('Political', 0)]
# Layer 19: Decoded intermediate outputs
# Attention mechanism [('которого', 3), ('ones', 1), ('yours', 1), ('hers', 1), ('celui', 0), ('orio', 0), ('verk', 0), ('Robin', 0), ('ink', 0), ('mine', 0)]
# Layer 20: Decoded intermediate outputs
# Attention mechanism [('iddle', 4), ('trivial', 3), ('question', 1), ('irrelevant', 1), ('ื', 1), ('ask', 1), ('answer', 0), ('answered', 0), ('asks', 0), ('@@', 0)]
# Layer 21: Decoded intermediate outputs
# Attention mechanism [('answered', 90), ('Answer', 5), ('answer', 2), ('answers', 0), ('Answer', 0), ('answering', 0), ('answer', 0), ('swers', 0), ('Question', 0), ('questions', 0)]
# Layer 22: Decoded intermediate outputs
# Attention mechanism [('questions', 49), ('Question', 12), ('question', 8), ('questions', 4), ('answers', 4), ('answered', 3), ('answering', 2), ('answer', 2), ('question', 2), ('Answer', 1)]
# Layer 23: Decoded intermediate outputs
# Attention mechanism [('Political', 38), ('political', 19), ('polit', 17), ('politics', 9), ('polit', 3), ('Polit', 1), ('politico', 0), ('polity', 0), ('político', 0), ('полі', 0)]
# Layer 24: Decoded intermediate outputs
# Attention mechanism [('Ukraine', 72), ('Russia', 3), ('China', 3), ('Palest', 2), ('Israel', 2), ('Iran', 1), ('Cuba', 1), ('Venezuela', 1), ('Ukrain', 1), ('Taiwan', 1)]
# Layer 25: Decoded intermediate outputs
# Attention mechanism [('American', 4), ('amer', 1), ('Ron', 0), ('America', 0), ('Social', 0), ('bin', 0), ('American', 0), ('a', 0), ('US', 0), ('social', 0)]
# Layer 26: Decoded intermediate outputs
# Attention mechanism [('current', 80), ('Current', 5), ('currently', 4), ('right', 2), ('current', 2), ('Current', 1), ('present', 0), ('today', 0), ('presently', 0), ('Currently', 0)]
# Layer 27: Decoded intermediate outputs
# Attention mechanism [('whether', 90), ('how', 8), ('why', 0), ('about', 0), ('what', 0), ('its', 0), ('How', 0), ('Whether', 0), (':\u2009', 0), ('how', 0)]
# Layer 28: Decoded intermediate outputs
# Attention mechanism [('rather', 2), ('TAG', 1), ('abstract', 1), ('Abstract', 0), ('curious', 0), ('deb', 0), ('深', 0), ('even', 0), ('sac', 0), ('miss', 0)]
# Layer 29: Decoded intermediate outputs
# Attention mechanism [('.', 97), ('…', 0), ('sw', 0), ('*.', 0), ('lo', 0), ('`.', 0), ('CLI', 0), ('sw', 0), ('ride', 0), ('/.', 0)]
# Layer 30: Decoded intermediate outputs
# Attention mechanism [('_', 84), ('addressed', 1), ('right', 0), ('________', 0), ('raised', 0), ('facing', 0), ('just', 0), ('faces', 0), ('asked', 0), ('now', 0)]
# Layer 31: Decoded intermediate outputs
# Attention mechanism [('...', 24), ('…', 22), ('..', 5), ('....', 3), ('...', 3), ('Democratic', 2), (',', 1), ('“', 1), ('question', 1), ('.', 0)]

# %%
=+model.reset_all()
layer = 14
model.get_logits('bananas')
attn = model.get_attn_activations(layer)
last_token_attn = attn[0][-1]
model.set_add_attn_output(layer, 0.6*last_token_attn)

# %%
model.generate_text('Pineapples are a delicious fruit', max_length=50)
# Out:
# 'Pineapples are a delicious fruit that can be eaten fresh or used in cooking. They are also a popular ingredient in many desserts and drinks.\nPineapples are a tropical fruit that is'

# %%
model.reset_all()
