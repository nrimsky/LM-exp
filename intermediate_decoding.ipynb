# %% [markdown]
# <a href="https://colab.research.google.com/github/nrimsky/LM-exp/blob/main/intermediate_decoding.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %%capture
# !pip install transformers

# %%
token = input("Enter your HF token: ")

# %%
import torch
from transformers import AutoTokenizer, AutoModelForCausalLM

class AttnWrapper(torch.nn.Module):
    def __init__(self, attn):
        super().__init__()
        self.attn = attn
        self.activations = None
        self.add_tensor = None

    def forward(self, *args, **kwargs):
        output = self.attn(*args, **kwargs)
        if self.add_tensor is not None:
            output = (output[0] + self.add_tensor,)+output[1:]
        self.activations = output[0]
        return output

    def reset(self):
        self.activations = None
        self.add_tensor = None

class BlockOutputWrapper(torch.nn.Module):
    def __init__(self, block, unembed_matrix, norm):
        super().__init__()
        self.block = block
        self.unembed_matrix = unembed_matrix
        self.norm = norm

        self.block.self_attn = AttnWrapper(self.block.self_attn)
        self.post_attention_layernorm = self.block.post_attention_layernorm

        self.attn_mech_output_unembedded = None
        self.intermediate_res_unembedded = None
        self.mlp_output_unembedded = None
        self.block_output_unembedded = None


    def forward(self, *args, **kwargs):
        output = self.block(*args, **kwargs)
        self.block_output_unembedded = self.unembed_matrix(self.norm(output[0]))
        attn_output = self.block.self_attn.activations
        self.attn_mech_output_unembedded = self.unembed_matrix(self.norm(attn_output))
        attn_output += args[0]
        self.intermediate_res_unembedded = self.unembed_matrix(self.norm(attn_output))
        mlp_output = self.block.mlp(self.post_attention_layernorm(attn_output))
        self.mlp_output_unembedded = self.unembed_matrix(self.norm(mlp_output))
        return output

    def attn_add_tensor(self, tensor):
        self.block.self_attn.add_tensor = tensor

    def reset(self):
        self.block.self_attn.reset()

    def get_attn_activations(self):
        return self.block.self_attn.activations

class Llama7BHelper:
    def __init__(self, token):
        self.device = "cuda" if torch.cuda.is_available() else "cpu"
        self.tokenizer = AutoTokenizer.from_pretrained("meta-llama/Llama-2-7b-hf", use_auth_token=token)
        self.model = AutoModelForCausalLM.from_pretrained("meta-llama/Llama-2-7b-hf", use_auth_token=token).to(self.device)
        for i, layer in enumerate(self.model.model.layers):
            self.model.model.layers[i] = BlockOutputWrapper(layer, self.model.lm_head, self.model.model.norm)

    def generate_text(self, prompt, max_length=100):
        inputs = self.tokenizer(prompt, return_tensors="pt")
        generate_ids = self.model.generate(inputs.input_ids.to(self.device), max_length=max_length)
        return self.tokenizer.batch_decode(generate_ids, skip_special_tokens=True, clean_up_tokenization_spaces=False)[0]

    def get_logits(self, prompt):
        inputs = self.tokenizer(prompt, return_tensors="pt")
        with torch.no_grad():
          logits = self.model(inputs.input_ids.to(self.device)).logits
          return logits

    def set_add_attn_output(self, layer, add_output):
        self.model.model.layers[layer].attn_add_tensor(add_output)

    def get_attn_activations(self, layer):
        return self.model.model.layers[layer].get_attn_activations()

    def reset_all(self):
        for layer in self.model.model.layers:
            layer.reset()

    def print_decoded_activations(self, decoded_activations, label):
        softmaxed = torch.nn.functional.softmax(decoded_activations[0][-1], dim=-1)
        values, indices = torch.topk(softmaxed, 10)
        probs_percent = [int(v * 100) for v in values.tolist()]
        tokens = self.tokenizer.batch_decode(indices.unsqueeze(-1))
        print(label, list(zip(tokens, probs_percent)))


    def decode_all_layers(self, text, topk=10, print_attn_mech=True, print_intermediate_res=True, print_mlp=True, print_block=True):
        self.get_logits(text)
        for i, layer in enumerate(self.model.model.layers):
            print(f'Layer {i}: Decoded intermediate outputs')
            if print_attn_mech:
                self.print_decoded_activations(layer.attn_mech_output_unembedded, 'Attention mechanism')
            if print_intermediate_res:
                self.print_decoded_activations(layer.intermediate_res_unembedded, 'Intermediate residual stream')
            if print_mlp:
                self.print_decoded_activations(layer.mlp_output_unembedded, 'MLP output')
            if print_block:
                self.print_decoded_activations(layer.block_output_unembedded, 'Block output')

# %%
model = Llama7BHelper(token)
# Out:
# Downloading (…)okenizer_config.json:   0%|          | 0.00/749 [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:1714: FutureWarning: The `use_auth_token` argument is deprecated and will be removed in v5 of Transformers.
#   warnings.warn(
# Downloading tokenizer.model:   0%|          | 0.00/500k [00:00<?, ?B/s]
# Downloading (…)/main/tokenizer.json:   0%|          | 0.00/1.84M [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/414 [00:00<?, ?B/s]
# Downloading (…)lve/main/config.json:   0%|          | 0.00/652 [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/transformers/modeling_utils.py:2193: FutureWarning: The `use_auth_token` argument is deprecated and will be removed in v5 of Transformers.
#   warnings.warn(
# Downloading (…)fetensors.index.json:   0%|          | 0.00/26.8k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/2 [00:00<?, ?it/s]
# Downloading (…)of-00002.safetensors:   0%|          | 0.00/9.98G [00:00<?, ?B/s]
# Downloading (…)of-00002.safetensors:   0%|          | 0.00/3.50G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# Downloading (…)neration_config.json:   0%|          | 0.00/175 [00:00<?, ?B/s]

# %%
model.decode_all_layers('Pineapples are a delicious fruit')
# Out:
# Layer 0: Decoded intermediate outputs
# Attention mechanism [('RU', 0), ('name', 0), ('', 0), ('folgender', 0), ('Alter', 0), ('finish', 0), ('intelligence', 0), ('help', 0), ('x', 0), ('solution', 0)]
# Intermediate residual stream [('ful', 3), ('fully', 1), ('务', 0), ('rinn', 0), ('halt', 0), ('Abstract', 0), ('anes', 0), ('psych', 0), ('pecies', 0), ('tree', 0)]
# MLP output [('ieu', 1), ('lessly', 0), ('konn', 0), ('exist', 0), ('iai', 0), ('老', 0), ('rinn', 0), ('ף', 0), ('haps', 0), ('tar', 0)]
# Block output [('ful', 3), ('fully', 2), ('rinn', 1), ('ieu', 1), ('lessly', 0), ('务', 0), ('老', 0), ('less', 0), ('configure', 0), ('resse', 0)]
# Layer 1: Decoded intermediate outputs
# Attention mechanism [('Drag', 2), ('%%%%', 1), ('ames', 1), ('RL', 0), ('références', 0), ('oct', 0), ('ali', 0), ('mud', 0), ('rot', 0), ('SS', 0)]
# Intermediate residual stream [('ful', 2), ('fully', 1), ('aggreg', 0), ('Kra', 0), ('mund', 0), ('rem', 0), ('cken', 0), ('roll', 0), ('Palmar', 0), ('asto', 0)]
# MLP output [('esto', 1), ('ful', 1), ('iness', 1), ('vim', 1), ('Maj', 0), ('men', 0), ('ewrite', 0), ('庄', 0), ('ier', 0), ('osoph', 0)]
# Block output [('ful', 12), ('mund', 2), ('rem', 1), ('fully', 1), ('iness', 0), ('phys', 0), ('esto', 0), ('tar', 0), ('asto', 0), ('tree', 0)]
# Layer 2: Decoded intermediate outputs
# Attention mechanism [('ölker', 1), ('Љ', 0), (':\u2009', 0), ('&=\\', 0), ('égr', 0), ('Censo', 0), ('rinn', 0), ('added', 0), ('Nem', 0), ('umber', 0)]
# Intermediate residual stream [('ful', 6), ('rem', 2), ('mund', 1), ('fully', 0), ('庄', 0), ('phys', 0), ('rinn', 0), ('tree', 0), ('Vil', 0), ('iness', 0)]
# MLP output [('arms', 1), ('ellers', 1), ('сло', 0), ('Fine', 0), ('count', 0), ('manifest', 0), ('olas', 0), ('ijn', 0), ('rollo', 0), ('vict', 0)]
# Block output [('ful', 2), ('rem', 0), ('mund', 0), ('phys', 0), ('esto', 0), ('iness', 0), ('tree', 0), ('trees', 0), ('fully', 0), ('ieu', 0)]
# Layer 3: Decoded intermediate outputs
# Attention mechanism [('voir', 0), ('ahu', 0), ('ijst', 0), ('від', 0), ('geb', 0), ('öß', 0), ('cation', 0), ('Љ', 0), ('ribución', 0), ('Aires', 0)]
# Intermediate residual stream [('庄', 1), ('mund', 0), ('ful', 0), ('Martí', 0), ('rem', 0), ('rinn', 0), ('iness', 0), ('ieu', 0), ('esto', 0), ('że', 0)]
# MLP output [('Dou', 4), ('carte', 1), ('boot', 1), ('raste', 0), ('iger', 0), ('град', 0), ('dou', 0), ('ious', 0), ('umps', 0), ('Haus', 0)]
# Block output [('ful', 1), ('Middle', 0), ('esto', 0), ('Ő', 0), ('aggreg', 0), ('resse', 0), ('iness', 0), ('庄', 0), ('hole', 0), ('phys', 0)]
# Layer 4: Decoded intermediate outputs
# Attention mechanism [('baar', 0), ('PU', 0), ('pf', 0), ('obb', 0), ('proc', 0), ('nn', 0), ('країн', 0), ('chr', 0), ('║', 0), ('oso', 0)]
# Intermediate residual stream [('rinn', 0), ('Middle', 0), ('ful', 0), ('hole', 0), ('ieu', 0), ('aggreg', 0), ('庄', 0), ('imb', 0), ('Kong', 0), ('öff', 0)]
# MLP output [('Perry', 1), ('nice', 0), ('lok', 0), ('overlap', 0), ('cier', 0), ('FA', 0), ('実', 0), ('jav', 0), ('kin', 0), ('▼', 0)]
# Block output [('nice', 3), ('tree', 1), ('Tree', 1), ('Kong', 0), ('trees', 0), ('resse', 0), ('ßen', 0), ('Lyon', 0), ('known', 0), ('Buff', 0)]
# Layer 5: Decoded intermediate outputs
# Attention mechanism [('LP', 1), ('captured', 0), ('dd', 0), ('nete', 0), ('象', 0), ('trick', 0), ('Desp', 0), ('uns', 0), ('門', 0), ('slave', 0)]
# Intermediate residual stream [('nice', 2), ('Kong', 1), ('ce', 1), ('Tree', 0), ('tree', 0), ('bu', 0), ('tempor', 0), ('нима', 0), ('resse', 0), ('业', 0)]
# MLP output [('widet', 1), ('stackexchange', 0), ('ms', 0), ('chestra', 0), ('ци', 0), ('tren', 0), ('icum', 0), ('raj', 0), ('stellen', 0), ('☺', 0)]
# Block output [('дой', 2), ('TS', 1), ('Ly', 1), ('dom', 0), ('tree', 0), ('orem', 0), ('庄', 0), ('ful', 0), ('ly', 0), ('nice', 0)]
# Layer 6: Decoded intermediate outputs
# Attention mechanism [('tex', 1), ('subt', 0), ('ASP', 0), ('美', 0), ('bre', 0), ('oid', 0), ('iona', 0), ('hosting', 0), ('Fichier', 0), ('onel', 0)]
# Intermediate residual stream [('庄', 1), ('ly', 0), ('дой', 0), ('shame', 0), ('fort', 0), ('loop', 0), ('tempor', 0), ('TS', 0), ('Toast', 0), ('trees', 0)]
# MLP output [('zew', 2), ('epen', 2), ('◄', 1), ('kur', 0), ('berga', 0), ('oł', 0), ('创', 0), (';;', 0), ('aya', 0), ('ffen', 0)]
# Block output [('Ly', 1), ('chev', 0), ('zan', 0), ('shame', 0), ('Ori', 0), ('�', 0), ('SOUR', 0), ('庄', 0), ('ivity', 0), ('Ψ', 0)]
# Layer 7: Decoded intermediate outputs
# Attention mechanism [('Prin', 1), ('soft', 0), ('tl', 0), ('ogo', 0), ('esk', 0), ('thro', 0), ('mask', 0), ('jak', 0), ('hat', 0), ('дж', 0)]
# Intermediate residual stream [('Ori', 1), ('Ly', 1), ('ly', 0), ('Ori', 0), ('Ψ', 0), ('shame', 0), ('Hat', 0), ('SOUR', 0), ('ber', 0), ('inflate', 0)]
# MLP output [('adamente', 3), ('Gemeins', 1), ('bos', 1), ('FAULT', 1), ('olis', 1), ('angen', 1), ('abei', 1), ('egy', 0), ('Leip', 0), ('heck', 0)]
# Block output [('тел', 1), ('Ori', 1), ('kin', 1), ('othek', 0), ('Ly', 0), ('Lauf', 0), ('ähr', 0), ('inflate', 0), ('chev', 0), ('tree', 0)]
# Layer 8: Decoded intermediate outputs
# Attention mechanism [('Cés', 1), ('hens', 1), ('ivel', 1), ('Janu', 0), ('César', 0), ('yen', 0), ('mn', 0), ('imar', 0), ('Њ', 0), ('magnet', 0)]
# Intermediate residual stream [('Lauf', 1), ('тел', 1), ('ähr', 1), ('Ori', 0), ('实', 0), ('kin', 0), ('ἡ', 0), ('시', 0), ('abei', 0), ('othek', 0)]
# MLP output [('aza', 2), ('remp', 0), ('理', 0), ('cier', 0), ('Tat', 0), ('virti', 0), ('bazie', 0), ('fen', 0), ('Morris', 0), ('člán', 0)]
# Block output [('othek', 1), ('cego', 0), ('ivity', 0), ('maste', 0), ('<%=', 0), ('ähr', 0), ('实', 0), ('rol', 0), ('onk', 0), ('sols', 0)]
# Layer 9: Decoded intermediate outputs
# Attention mechanism [('rott', 1), ('ソ', 1), ('zung', 0), ('ilio', 0), ('yr', 0), ('dm', 0), ('urity', 0), ('editor', 0), ('lap', 0), ('yci', 0)]
# Intermediate residual stream [('<%=', 1), ('ähr', 1), ('sols', 1), ('othek', 0), ('ivity', 0), ('maste', 0), ('cego', 0), ('实', 0), ('Rot', 0), ('öß', 0)]
# MLP output [('prü', 4), ('zt', 1), ('кло', 1), ('enas', 1), ('◄', 0), ('IMDb', 0), ('clus', 0), ('branch', 0), ('znik', 0), ('ulaire', 0)]
# Block output [('<%=', 1), ('othek', 1), ('germeister', 0), ('sols', 0), ('kund', 0), ('stackoverflow', 0), ('◄', 0), ('cego', 0), ('живело', 0), ('rol', 0)]
# Layer 10: Decoded intermediate outputs
# Attention mechanism [('Lad', 4), ('uses', 1), ('Sky', 1), ('rand', 0), ('incorpor', 0), ('Masters', 0), ('Fra', 0), ('puis', 0), ('susp', 0), ('rand', 0)]
# Intermediate residual stream [('<%=', 1), ('othek', 1), ('germeister', 0), ('sols', 0), ('живело', 0), ('kund', 0), ('тел', 0), ('◄', 0), ('ele', 0), ('산', 0)]
# MLP output [('nod', 0), ('rès', 0), ('Tsch', 0), ('antin', 0), ('ány', 0), ('izo', 0), ('></', 0), ('forget', 0), ('лом', 0), ('нах', 0)]
# Block output [('живело', 2), ('тел', 1), ('산', 0), ('othek', 0), ('Rot', 0), ('origine', 0), ('maste', 0), ('тиче', 0), ('untu', 0), ('<%=', 0)]
# Layer 11: Decoded intermediate outputs
# Attention mechanism [('tek', 2), ('Herr', 0), ('reso', 0), ('sche', 0), ('parenthes', 0), ('府', 0), ('etto', 0), ('➖', 0), ('identifier', 0), ('tor', 0)]
# Intermediate residual stream [('живело', 1), ('тел', 1), ('origine', 0), ('산', 0), ('Rot', 0), ('othek', 0), ('тиче', 0), ('cego', 0), ('maste', 0), ('<%=', 0)]
# MLP output [('kens', 2), ('Hend', 1), ('ema', 1), ('jan', 0), ('sg', 0), ('aze', 0), ('ppa', 0), ('fic', 0), ('íd', 0), ('buntu', 0)]
# Block output [('cego', 1), ('живело', 0), ('frak', 0), ('ár', 0), ('ध', 0), ('untu', 0), ('rol', 0), ('origine', 0), ('vá', 0), ('тел', 0)]
# Layer 12: Decoded intermediate outputs
# Attention mechanism [('ały', 2), ('iter', 1), ('autorité', 0), ('itsch', 0), ('Mem', 0), ('ipe', 0), ('Tras', 0), ('itung', 0), ('alone', 0), ('enschaft', 0)]
# Intermediate residual stream [('живело', 0), ('ly', 0), ('cego', 0), ('ध', 0), ('Lauf', 0), ('origine', 0), ('warn', 0), ('untu', 0), ('Bast', 0), ('nice', 0)]
# MLP output [('vard', 2), ('rinn', 1), ('они', 1), ('Detroit', 1), ('ulas', 0), ('AXI', 0), ('UTC', 0), ('Navar', 0), ('oe', 0), ('LOG', 0)]
# Block output [('cego', 0), ('PDO', 0), ('ogli', 0), ('gg', 0), ('nice', 0), ('naio', 0), ('origine', 0), ('ly', 0), ('mouse', 0), ('warn', 0)]
# Layer 13: Decoded intermediate outputs
# Attention mechanism [('steller', 2), ('drawable', 1), ('Lauf', 1), ('esia', 0), ('hens', 0), ('iddle', 0), ('vironment', 0), ('perty', 0), ('пар', 0), ('ião', 0)]
# Intermediate residual stream [('ogli', 1), ('naio', 0), ('origine', 0), ('PDO', 0), ('rinn', 0), ('ly', 0), ('gg', 0), ('cego', 0), ('untu', 0), ('ließ', 0)]
# MLP output [('ahn', 1), ('blatt', 1), ('iers', 0), ('коли', 0), ('ATH', 0), ('Украї', 0), ('ово', 0), ('того', 0), ('fly', 0), ('oot', 0)]
# Block output [('origine', 1), ('rinn', 0), ('cego', 0), ('trees', 0), ('ly', 0), ('々', 0), ('mouse', 0), ('Ly', 0), ('gat', 0), ('tree', 0)]
# Layer 14: Decoded intermediate outputs
# Attention mechanism [('andas', 2), ('pad', 2), ('omp', 1), ('Kop', 0), ('aso', 0), ('vironment', 0), ('dor', 0), ('vu', 0), ('itet', 0), ('dm', 0)]
# Intermediate residual stream [('origine', 1), ('gat', 0), ('ly', 0), ('rinn', 0), ('trees', 0), ('Ly', 0), ('frak', 0), ('rola', 0), ('endre', 0), ('々', 0)]
# MLP output [('Trop', 2), ('̀', 1), ('zen', 1), ('BD', 0), ('yman', 0), ('incor', 0), ('🌍', 0), ('stag', 0), ('tens', 0), ('́', 0)]
# Block output [('Ly', 1), ('dom', 0), ('zös', 0), ('kin', 0), ('origine', 0), ('endre', 0), ('agnet', 0), ('ly', 0), ('trees', 0), ('gat', 0)]
# Layer 15: Decoded intermediate outputs
# Attention mechanism [('urable', 1), ('uro', 1), ('ɨ', 1), ('Ä', 0), ('ly', 0), ('Ly', 0), ('py', 0), ('ด', 0), ('wd', 0), ('getElement', 0)]
# Intermediate residual stream [('Ly', 3), ('dom', 1), ('ly', 1), ('origine', 1), ('zös', 0), ('kin', 0), ('gat', 0), ('known', 0), ('PDO', 0), ('trees', 0)]
# MLP output [('Wikip', 2), ('iante', 1), ('konn', 1), ('Wayback', 0), ('icult', 0), ('iv', 0), ('iesz', 0), ('Marie', 0), ('coli', 0), ('emu', 0)]
# Block output [('Ly', 2), ('zös', 1), ('known', 1), ('rinn', 0), ('agnet', 0), ('cowo', 0), ('trees', 0), ('々', 0), ('dom', 0), ('naio', 0)]
# Layer 16: Decoded intermediate outputs
# Attention mechanism [('but', 2), ('but', 1), ('ġ', 1), ('&=\\', 1), ('Symbol', 1), ('odu', 0), ('pero', 0), ('ri', 0), ('symbol', 0), ('inois', 0)]
# Intermediate residual stream [('zös', 3), ('cowo', 2), ('known', 1), ('agnet', 1), ('rinn', 0), ('Toast', 0), ('Ly', 0), ('PDO', 0), ('dom', 0), ('живело', 0)]
# MLP output [('native', 4), ('Native', 1), ('bits', 1), ('город', 1), ('spiel', 1), ('native', 0), ('accom', 0), ('roe', 0), ('ね', 0), ('MY', 0)]
# Block output [('known', 3), ('native', 1), ('cowo', 1), ('zös', 1), ('dom', 1), ('ri', 0), ('agnet', 0), ('lein', 0), ('that', 0), ('trees', 0)]
# Layer 17: Decoded intermediate outputs
# Attention mechanism [('They', 5), ('they', 5), ('ones', 3), ('ogo', 3), ('{|', 1), ('They', 1), ('they', 1), ('Einzelnach', 0), ('themselves', 0), ('oko', 0)]
# Intermediate residual stream [('known', 3), ('zös', 2), ('native', 2), ('cowo', 1), ('agnet', 1), ('dom', 0), ('native', 0), ('ri', 0), ('naio', 0), ('known', 0)]
# MLP output [('败', 1), ('inton', 1), ('NT', 1), ('Guard', 0), ('vil', 0), ('erton', 0), ('hat', 0), ('Scala', 0), ('igen', 0), ('stro', 0)]
# Block output [('native', 4), ('known', 4), ('zös', 3), ('cowo', 1), ('agnet', 1), ('native', 1), ('Toast', 1), ('naio', 0), ('lein', 0), ('败', 0)]
# Layer 18: Decoded intermediate outputs
# Attention mechanism [('Rotten', 3), ('pun', 3), ('imit', 1), ('indeed', 1), ('ähr', 1), ('Indeed', 0), ('izont', 0), ('�', 0), ('urls', 0), ('za', 0)]
# Intermediate residual stream [('native', 4), ('zös', 3), ('known', 3), ('cowo', 1), ('naio', 1), ('native', 0), ('Toast', 0), ('agnet', 0), ('败', 0), ('Portail', 0)]
# MLP output [('Хронологија', 24), ('known', 12), ('Kn', 2), ('Попис', 1), ('lets', 0), ('ropol', 0), ('ída', 0), ('cade', 0), ('but', 0), ('ље', 0)]
# Block output [('known', 21), ('native', 3), ('cowo', 3), ('known', 1), ('zös', 1), ('native', 1), ('naio', 1), ('indeed', 0), ('wall', 0), ('trees', 0)]
# Layer 19: Decoded intermediate outputs
# Attention mechanism [('summer', 9), ('summ', 3), ('aku', 2), ('Хронологија', 2), ('Summer', 1), ('Sommer', 1), ('bah', 1), ('puesta', 1), ('opera', 0), ('�', 0)]
# Intermediate residual stream [('known', 14), ('native', 3), ('cowo', 2), ('known', 1), ('native', 0), ('indeed', 0), ('zös', 0), ('naio', 0), ('wall', 0), ('dom', 0)]
# MLP output [('Loop', 15), ('loop', 10), ('loop', 9), ('loops', 8), ('Loop', 4), ('fruit', 3), ('virti', 1), ('果', 1), ('adel', 0), ('rix', 0)]
# Block output [('known', 6), ('native', 2), ('cowo', 1), ('zös', 1), ('ri', 1), ('native', 1), ('lein', 0), ('Portail', 0), ('leben', 0), ('tele', 0)]
# Layer 20: Decoded intermediate outputs
# Attention mechanism [('fruit', 99), ('果', 0), ('ruits', 0), ('tropical', 0), ('apple', 0), ('produce', 0), ('dess', 0), ('food', 0), ('apple', 0), ('ruit', 0)]
# Intermediate residual stream [('known', 5), ('native', 3), ('ri', 1), ('cowo', 1), ('native', 1), ('zös', 1), ('tele', 0), ('lein', 0), ('indeed', 0), ('trees', 0)]
# MLP output [('LENG', 2), ('gard', 1), ('botan', 1), ('trees', 1), ('garden', 1), ('Garden', 0), ('plants', 0), ('fal', 0), ('stor', 0), ('лю', 0)]
# Block output [('known', 10), ('native', 4), ('ri', 2), ('trees', 1), ('native', 1), ('tele', 0), ('whose', 0), ('cowo', 0), ('known', 0), ('fruit', 0)]
# Layer 21: Decoded intermediate outputs
# Attention mechanism [('pine', 3), ('native', 3), ('©', 1), ('ston', 1), ('sierp', 1), ('kwiet', 0), ('rache', 0), ('enze', 0), ('itore', 0), ('pic', 0)]
# Intermediate residual stream [('known', 11), ('native', 7), ('ri', 3), ('native', 3), ('trees', 1), ('whose', 0), ('known', 0), ('tele', 0), ('cowo', 0), ('ambiguation', 0)]
# MLP output [('Хронологија', 16), ('rich', 3), ('pack', 3), ('stra', 3), ('kehr', 1), ('stract', 1), ('metros', 1), ('stra', 1), ('reichen', 0), ('ensoort', 0)]
# Block output [('known', 10), ('native', 9), ('ri', 7), ('native', 3), ('Хронологија', 1), ('tele', 0), ('ensoort', 0), ('trees', 0), ('strap', 0), ('lein', 0)]
# Layer 22: Decoded intermediate outputs
# Attention mechanism [('eat', 82), ('食', 1), ('ї', 0), ('food', 0), ('favour', 0), ('料', 0), ('dess', 0), ('dinner', 0), ('favorite', 0), ('consumption', 0)]
# Intermediate residual stream [('known', 8), ('native', 7), ('ri', 6), ('native', 2), ('Хронологија', 1), ('ensoort', 0), ('trees', 0), ('Kontrola', 0), ('tele', 0), ('Portail', 0)]
# MLP output [('full', 98), ('full', 1), ('Full', 0), ('Full', 0), ('filled', 0), ('loaded', 0), ('pack', 0), ('that', 0), ('overflow', 0), ('filled', 0)]
# Block output [('ri', 12), ('native', 8), ('known', 4), ('that', 3), ('native', 1), ('rich', 1), ('full', 1), ('ensoort', 1), ('full', 0), ('Хронологија', 0)]
# Layer 23: Decoded intermediate outputs
# Attention mechanism [('ampio', 2), ('Хронологија', 1), ('anza', 1), ('äler', 1), ('architecture', 1), ('мин', 1), ('anterie', 1), ('ionale', 0), ('lage', 0), ('Zahl', 0)]
# Intermediate residual stream [('ri', 8), ('native', 6), ('known', 5), ('that', 2), ('native', 1), ('Хронологија', 1), ('ensoort', 1), ('rich', 1), ('full', 1), ('full', 1)]
# MLP output [('bo', 19), ('ind', 13), ('grow', 5), ('native', 5), ('�', 1), ('har', 1), ('grown', 1), ('grows', 1), ('growing', 0), ('lag', 0)]
# Block output [('native', 22), ('ri', 10), ('native', 4), ('known', 3), ('Хронологија', 2), ('that', 2), ('rich', 1), ('ensoort', 1), ('Kontrola', 0), ('full', 0)]
# Layer 24: Decoded intermediate outputs
# Attention mechanism [('\u200a', 30), ('tropical', 15), ('fruit', 2), ('\u200d', 1), ('Hawai', 1), ('\u200b', 0), ('—', 0), ('\ufeff', 0), ('Malays', 0), ('Trop', 0)]
# Intermediate residual stream [('native', 24), ('ri', 11), ('native', 4), ('known', 4), ('that', 2), ('Хронологија', 1), ('rich', 1), ('Kontrola', 0), ('pack', 0), ('pack', 0)]
# MLP output [('however', 42), ('good', 1), ('typen', 0), ('conne', 0), ('tot', 0), ('però', 0), ('good', 0), ('nof', 0), ('tut', 0), ('aug', 0)]
# Block output [('native', 22), ('ri', 7), ('native', 5), ('known', 5), ('Хронологија', 4), ('that', 2), ('Kontrola', 1), ('rich', 1), ('ensoort', 0), ('servable', 0)]
# Layer 25: Decoded intermediate outputs
# Attention mechanism [('yet', 95), ('Yet', 1), ('but', 0), ('thanks', 0), ('whether', 0), ('cour', 0), ('when', 0), ('aren', 0), ('however', 0), ('but', 0)]
# Intermediate residual stream [('native', 21), ('ri', 6), ('native', 5), ('known', 5), ('Хронологија', 4), ('that', 2), ('Kontrola', 1), ('rich', 1), ('ensoort', 0), ('pack', 0)]
# MLP output [('with', 3), ('best', 2), ('Table', 0), ('ecz', 0), ('Mother', 0), ('анд', 0), ('you', 0), ('perfect', 0), ('owan', 0), ('itar', 0)]
# Block output [('native', 17), ('ri', 12), ('that', 4), ('native', 2), ('known', 2), ('Хронологија', 2), ('rich', 0), ('Kontrola', 0), ('pack', 0), ('ensoort', 0)]
# Layer 26: Decoded intermediate outputs
# Attention mechanism [('island', 4), ('national', 3), ('islands', 3), ('season', 1), ('nation', 0), ('Island', 0), ('Islands', 0), ('\xa0', 0), ('commercial', 0), ('wed', 0)]
# Intermediate residual stream [('native', 20), ('ri', 13), ('that', 4), ('known', 3), ('native', 2), ('Хронологија', 1), ('rich', 1), ('pack', 0), ('Kontrola', 0), ('ensoort', 0)]
# MLP output [('bel', 99), ('bel', 0), ('Bel', 0), ('Bel', 0), ('elt', 0), ('believe', 0), ('stuff', 0), ('burst', 0), ('stra', 0), ('rever', 0)]
# Block output [('native', 20), ('ri', 16), ('that', 2), ('known', 2), ('Хронологија', 2), ('native', 2), ('bel', 1), ('rip', 0), ('ensoort', 0), ('rich', 0)]
# Layer 27: Decoded intermediate outputs
# Attention mechanism [('that', 8), ('alone', 4), ('!', 4), ('onnées', 3), ('but', 3), ('Their', 2), (',[', 2), ('and', 2), (',', 1), ('their', 1)]
# Intermediate residual stream [('native', 21), ('ri', 12), ('that', 5), ('known', 3), ('Хронологија', 3), ('native', 2), ('bel', 1), ('ensoort', 0), ('rip', 0), ('pri', 0)]
# MLP output [('e', 100), ('with', 0), ('with', 0), ('eg', 0), ('c', 0), ('people', 0), ('found', 0), ('ev', 0), ('tra', 0), ('full', 0)]
# Block output [('native', 35), ('ri', 9), ('that', 6), ('known', 3), ('bel', 2), ('native', 2), ('pri', 1), ('found', 0), ('Хронологија', 0), ('full', 0)]
# Layer 28: Decoded intermediate outputs
# Attention mechanism [('addition', 7), ('del', 3), ('tre', 3), ('option', 2), ('item', 1), ('treat', 1), ('sweet', 1), ('Del', 1), ('DataSource', 0), ('Del', 0)]
# Intermediate residual stream [('native', 33), ('ri', 11), ('that', 5), ('known', 3), ('bel', 2), ('native', 2), ('pri', 1), ('rip', 0), ('found', 0), ('rich', 0)]
# MLP output [('year', 86), ('high', 10), ('no', 1), ('Year', 0), ('worth', 0), ('High', 0), ('high', 0), ('year', 0), ('no', 0), ('low', 0)]
# Block output [('native', 39), ('that', 14), ('ri', 4), ('year', 2), ('found', 2), ('pri', 1), ('full', 1), ('rich', 1), ('burst', 1), ('bel', 1)]
# Layer 29: Decoded intermediate outputs
# Attention mechanism [('cut', 78), ('cut', 9), ('ref', 5), ('cutting', 1), ('ref', 0), ('fruit', 0), ('f', 0), ('P', 0), ('Ref', 0), ('delivery', 0)]
# Intermediate residual stream [('native', 36), ('that', 15), ('ri', 4), ('year', 2), ('found', 2), ('pri', 1), ('full', 1), ('rich', 1), ('bel', 1), ('burst', 1)]
# MLP output [('whether', 14), ('well', 13), ('–', 2), ('!', 2), ('!!', 1), ('e', 1), ('that', 1), ('so', 1), ('tree', 1), ('name', 1)]
# Block output [('that', 31), ('native', 31), ('year', 2), ('ri', 1), ('found', 1), ('full', 1), ('e', 1), ('burst', 1), ('pri', 0), ('with', 0)]
# Layer 30: Decoded intermediate outputs
# Attention mechanism [('found', 17), ('origin', 6), ('[', 5), ('obtained', 2), ('can', 1), ('available', 1), ('found', 0), ('thought', 0), ('certainly', 0), ('grow', 0)]
# Intermediate residual stream [('native', 33), ('that', 33), ('found', 2), ('year', 1), ('e', 1), ('full', 1), ('ri', 1), ('burst', 1), ('with', 0), ('but', 0)]
# MLP output [(',', 44), ('.', 31), ('(', 10), ('and', 4), ('\n', 4), (';', 1), ('I', 0), ('to', 0), ('that', 0), ('with', 0)]
# Block output [('that', 84), (',', 6), ('with', 2), ('.', 1), ('and', 0), ('native', 0), ('but', 0), ('which', 0), ('e', 0), ('found', 0)]
# Layer 31: Decoded intermediate outputs
# Attention mechanism [('flav', 18), ('botan', 5), ('taste', 4), ('genus', 2), ('native', 2), ('species', 1), ('family', 1), ('tropical', 1), ('naturally', 1), (',', 1)]
# Intermediate residual stream [('that', 81), (',', 8), ('with', 2), ('.', 1), ('native', 1), ('and', 1), ('but', 0), ('which', 0), ('!', 0), ('to', 0)]
# MLP output [('belonging', 6), ('filled', 3), ('suitable', 2), ('composed', 2), ('flav', 1), ('containing', 1), ('fitted', 1), ('offering', 1), ('consisting', 0), ('worthy', 0)]
# Block output [('that', 45), (',', 16), ('.', 6), ('and', 6), ('with', 6), ('which', 1), ('to', 1), ('but', 1), ('native', 1), ('known', 0)]

# %%
model.reset_all()
layer = 14
model.get_logits('bananas')
attn = model.get_attn_activations(layer)
last_token_attn = attn[0][-1]
model.set_add_attn_output(layer, 0.6*last_token_attn)

# %%
model.generate_text('Pineapples are a delicious fruit', max_length=50)
# Out:
# 'Pineapples are a delicious fruit that can be eaten fresh or used in cooking. They are also a popular ingredient in many desserts and drinks.\nPineapples are a tropical fruit that is'

# %%
model.reset_all()
